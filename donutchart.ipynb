# %%
# %matplotlib inline

# %%
# from https://stackoverflow.com/a/44154062

import matplotlib.pyplot as plt
import numpy as np

fig, ax = plt.subplots()
ax.axis('equal')
width = 0.3

cm = plt.get_cmap("viridis")
cout = cm(np.arange(3)*4)
pie, _ = ax.pie([120,77,39], radius=1, labels=list("ABC"), colors=cout)
plt.setp( pie, width=width, edgecolor='white')

cin = cm(np.array([1,2,5,6,9,10]))
labels = map("".join, zip(list("aabbcc"),map(str, [1,2]*3)))
pie2, _ = ax.pie([60,60,37,40,29,10], radius=1-width, labels=labels,
                                      labeldistance=0.7, colors=cin)
plt.setp( pie2, width=width, edgecolor='white')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-11bbbfd42690> in <module>()
#      16 labels = map("".join, zip(list("aabbcc"),map(str, [1,2]*3)))
#      17 pie2, _ = ax.pie([60,60,37,40,29,10], radius=1-width, labels=labels,
# ---> 18                                       labeldistance=0.7, colors=cin)
#      19 plt.setp( pie2, width=width, edgecolor='white')
#      20 plt.show()
#
# /usr/lib/python3/dist-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1892                     warnings.warn(msg % (label_namer, func.__name__),
#    1893                                   RuntimeWarning, stacklevel=2)
# -> 1894             return func(ax, *args, **kwargs)
#    1895         pre_doc = inner.__doc__
#    1896         if pre_doc is None:
#
# /usr/lib/python3/dist-packages/matplotlib/axes/_axes.py in pie(self, x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame)
#    2583         if explode is None:
#    2584             explode = [0] * len(x)
# -> 2585         if len(x) != len(labels):
#    2586             raise ValueError("'label' must be of length 'x'")
#    2587         if len(x) != len(explode):
#
# TypeError: object of type 'map' has no len()
